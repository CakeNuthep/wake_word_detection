# %% [markdown]
# <a href="https://colab.research.google.com/github/CakeNuthep/wake_word_detection/blob/main/wake_word_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/robin-ai-ml/ML-KWS-for-MCU.git
# Out:
# fatal: destination path 'ML-KWS-for-MCU' already exists and is not an empty directory.

# %%
# !pip uninstall tensorflow
# Out:
# Uninstalling tensorflow-1.13.2:
#   Would remove:
#     /usr/local/bin/freeze_graph
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-1.13.2.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? ืัy
# Your response ('ืัy') was not one of the expected responses: y, n
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-1.13.2

# %%
# !pip install tensorflow==1.13.2
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/bc/70/45d3b9fab768215a2055c7819d39547a4b0b7401b4583094068741aff99b/tensorflow-1.13.2-cp37-cp37m-manylinux1_x86_64.whl
# ...

# %%
# !mkdir -p /content/tmp/speech_commands_v0.02
# !curl -o /content/tmp/speech_commands_v0.02/speech_commands_v0.02.tar.gz -fSsL http://download.tensorflow.org/data/speech_commands_v0.02.tar.gz
# !cd  /content/tmp/speech_commands_v0.02 && tar xzf speech_commands_v0.02.tar.gz

# %%
# !python /content/ML-KWS-for-MCU/train.py --model_architecture dnn --batch_size 1 --model_size_info 128 128 128 --data_dir  /content/tmp/speech_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:tensorflow:Step #13205: rate 0.001000, accuracy 0.00%, cross entropy 2.222052
# INFO:tensorflow:Step #13206: rate 0.001000, accuracy 100.00%, cross entropy 1.729711
# INFO:tensorflow:Step #13207: rate 0.001000, accuracy 0.00%, cross entropy 3.724411
# INFO:tensorflow:Step #13208: rate 0.001000, accuracy 0.00%, cross entropy 3.053449
# INFO:tensorflow:Step #13209: rate 0.001000, accuracy 100.00%, cross entropy 1.161981
# INFO:tensorflow:Step #13210: rate 0.001000, accuracy 0.00%, cross entropy 2.168606
# INFO:tensorflow:Step #13211: rate 0.001000, accuracy 0.00%, cross entropy 2.648297
# INFO:tensorflow:Step #13212: rate 0.001000, accuracy 100.00%, cross entropy 0.692468
# INFO:tensorflow:Step #13213: rate 0.001000, accuracy 0.00%, cross entropy 2.796783
# INFO:tensorflow:Step #13214: rate 0.001000, accuracy 100.00%, cross entropy 1.331493
# INFO:tensorflow:Step #13215: rate 0.001000, accuracy 100.00%, cross entropy 0.207183
# ...

# %%
# !ls /tmp/speech_commands_train/best
# Out:
# checkpoint
# dnn_4843.ckpt-16400.data-00000-of-00001
# dnn_4843.ckpt-16400.index
# dnn_4843.ckpt-16400.meta
# dnn_4992.ckpt-16800.data-00000-of-00001
# dnn_4992.ckpt-16800.index
# dnn_4992.ckpt-16800.meta
# dnn_5007.ckpt-17200.data-00000-of-00001
# dnn_5007.ckpt-17200.index
# dnn_5007.ckpt-17200.meta
# dnn_5086.ckpt-17600.data-00000-of-00001
# dnn_5086.ckpt-17600.index
# dnn_5086.ckpt-17600.meta
# dnn_5149.ckpt-18000.data-00000-of-00001
# dnn_5149.ckpt-18000.index
# dnn_5149.ckpt-18000.meta

# %%
#ต้องแก้ไขในไฟล์ test.py จากคำสั่ง xrange เป็นคำสั่ง range แทน

# %%
# !python /content/ML-KWS-for-MCU/test.py --model_architecture dnn --model_size_info 128 128 128 --checkpoint /tmp/speech_commands_train/best/dnn_5007.ckpt-17200 --data_dir  /content/tmp/speech_dataset
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
